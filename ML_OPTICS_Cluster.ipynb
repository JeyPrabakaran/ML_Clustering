# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import OPTICS
from sklearn.preprocessing import StandardScaler

# %%
# Load the data
data = pd.read_csv('Mall_Customers.csv')

# %%
# Select features (let's assume 'Annual Income (k$)' and 'Spending Score (1-100)')
X = data[['Annual Income (k$)', 'Spending Score (1-100)']]

# %%
# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Apply OPTICS clustering
optics = OPTICS(min_samples=5, xi=0.05, min_cluster_size=0.05)
cluster_labels = optics.fit_predict(X_scaled)

# %%
# Plot reachability plot
'''
Reachability Plot: The reachability plot is a line plot where each point is represented 
on the x-axis by its position in the ordered dataset and 
on the y-axis by its reachability distance. The plot shows how the reachability distance 
varies as we move through the ordered points.
'''
plt.figure(figsize=(10, 6))
plt.title('OPTICS Clustering - Reachability Plot')
plt.plot(np.arange(len(clustering.reachability_)), np.sort(clustering.reachability_), marker='*')
plt.xlabel('Points')
plt.ylabel('Reachability Distance')
plt.show()

# %%
# Plot clusters
plt.figure(figsize=(10, 6))
plt.title('OPTICS Clustering - Clusters')
plt.scatter(X[:, 0], X[:, 1], c=clustering.labels_, cmap='viridis', marker='*')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
# Load the data
data = pd.read_csv('Mall_Customers.csv')

# %%
# Select features (let's assume 'Age', 'Annual Income (k$)', and 'Spending Score (1-100)')
X = data[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']]

# %%
# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Apply OPTICS clustering
optics = OPTICS(min_samples=5, xi=0.05, min_cluster_size=0.05)
cluster_labels = optics.fit_predict(X_scaled)

# %%
# Plotting the clusters in 3D
fig = plt.figure(figsize=(14, 12))
ax = fig.add_subplot(111, projection='3d')
# Plotting data points with cluster labels
for cluster_label in np.unique(cluster_labels):
    ax.scatter(X.loc[cluster_labels == cluster_label, 'Age'],
               X.loc[cluster_labels == cluster_label, 'Annual Income (k$)'],
               X.loc[cluster_labels == cluster_label, 'Spending Score (1-100)'],
               label=f'Cluster {cluster_label}', cmap='viridis',marker=f'${cluster_label}$')
# Labeling the axes
ax.set_xlabel('Age')
ax.set_ylabel('Annual Income (k$)')
ax.set_zlabel('Spending Score (1-100)')
ax.set_title('OPTICS Clustering')
ax.legend()

plt.show()
# Out:
# C:\Users\Prabakaran J\AppData\Local\Temp\ipykernel_29472\1962868231.py:6: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(X.loc[cluster_labels == cluster_label, 'Age'],
