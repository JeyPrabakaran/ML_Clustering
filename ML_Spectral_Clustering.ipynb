# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralClustering
from sklearn.preprocessing import StandardScaler

# %%
# Load data from CSV
data = pd.read_csv('Mall_Customers.csv')

# %%
#X = data.iloc[:, 3:5]
#X
# Let's assume you want to cluster based on 'Annual Income (k$)' and 'Spending Score (1-100)'
X = data[['Annual Income (k$)', 'Spending Score (1-100)']]

# %%
# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Applying spectral clustering
spectral_clustering = SpectralClustering(n_clusters=5, assign_labels='discretize', random_state=0)
cluster_labels = spectral_clustering.fit_predict(X_scaled)

# %%
# Add cluster labels to the DataFrame
data['Cluster'] = cluster_labels

# %%
# Plotting with Seaborn
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Annual Income (k$)', y='Spending Score (1-100)', hue='Cluster', data=data, palette='viridis')
plt.title('Spectral Clustering')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.show()
